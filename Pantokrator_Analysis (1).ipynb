# %% [markdown]
# # **Critical Analysis of Iconographic Data: Global Databases vs. Regional Study of the Samokov School**

# %% [markdown]
# ### **1. Introduction and Sample Rationale**

# %% [markdown]
# This research addresses a critical paradox in contemporary Digital Humanities: the gap between global information datasets and regional cultural specificities. The initial database was compiled by extracting information from leading Western institutions (The Metropolitan Museum of Art, The British Museum, Europeana), which define the "visibility" of Christian art within the global digital network.
#
# However, this selection inevitably carries the risk of Eurocentric bias, which undeservedly underestimates certain territories. Bulgaria, acting as a cultural bridge and a guardian of the conservative Christian tradition under centuries of isolation (comparable only to the Spanish Reconquista), offers a unique model that global scholarship often "misses" due to a lack of digitized data.
#
# Positioned at the geopolitical crossroads between East and West, Bulgarian culture preserved its Christian identity within the unique environment of centuries-long Ottoman rule—a historical fate that finds its only parallel in the Iberian Peninsula. The result was the formation of a specific, resilient, and deeply conservative intangible culture that preserved authentic Byzantine models while simultaneously transforming them through the lens of the local National Revival. The absence of this data in major digital archives is not merely a statistical omission; it is a systemic erasure of one of the richest cultural layers in global art history.

# %% [markdown]
# ### **2. Preliminary Results (Code & Visualization)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
artworks_data = [
    {"id": 1, "title": "Christ in Majesty (Sant Climent de Taull)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Spain", "museum_site": "MNAC / original site", "medium": "Fresco", "throne": 1, "mandorla": 1, "book_open": 1, "halo_cross": 1},
    {"id": 2, "title": "Maiestas Domini (San Isidoro de Leon)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Spain", "museum_site": "Basilica of San Isidoro", "medium": "Fresco", "throne": 1, "mandorla": 1, "book_open": 1, "halo_cross": 1},
    {"id": 3, "title": "Christ in Majesty (Urgell frontal)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Spain", "museum_site": "Museu Diocesa d’Urgell", "medium": "Panel", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 4, "title": "Christ in Majesty (Vic frontal)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Spain", "museum_site": "Museu Episcopal de Vic", "medium": "Panel", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 5, "title": "Maiestas Domini (Moissac Portal)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "France", "museum_site": "Abbey of Saint-Pierre", "medium": "Relief", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 6, "title": "Christ in Majesty (Autun Tympanum)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "France", "museum_site": "Autun Cathedral", "medium": "Relief", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 7, "title": "Christ in Majesty (Conques)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "France", "museum_site": "Sainte-Foy Abbey", "medium": "Relief", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 8, "title": "Maiestas Domini (Chartres Royal Portal)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "France", "museum_site": "Chartres Cathedral", "medium": "Relief", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 9, "title": "Christ in Majesty (Vezelay)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "France", "museum_site": "Basilica of Vezelay", "medium": "Relief", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 10, "title": "Christ in Majesty (Torcello Mosaic)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Italy", "museum_site": "Torcello Cathedral", "medium": "Mosaic", "throne": 1, "mandorla": 1, "book_open": 1, "halo_cross": 1},
    {"id": 11, "title": "Christ in Majesty (Monreale Apse)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Italy", "museum_site": "Monreale Cathedral", "medium": "Mosaic", "throne": 1, "mandorla": 1, "book_open": 1, "halo_cross": 1},
    {"id": 12, "title": "Christ in Majesty (Cefalu Apse)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Italy", "museum_site": "Cefalu Cathedral", "medium": "Mosaic", "throne": 1, "mandorla": 1, "book_open": 1, "halo_cross": 1},
    {"id": 13, "title": "Maiestas Domini (San Clemente Rome)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "Italy", "museum_site": "Basilica di San Clemente", "medium": "Mosaic", "throne": 1, "mandorla": 1, "book_open": 1, "halo_cross": 1},
    {"id": 14, "title": "Christ in Majesty (Florence Baptistery)", "tradition": "Western", "type": "Maiestas", "century": 13, "country": "Italy", "museum_site": "Baptistery of Florence", "medium": "Mosaic", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 15, "title": "Maiestas Domini (Pisa Duomo)", "tradition": "Western", "type": "Maiestas", "century": 13, "country": "Italy", "museum_site": "Pisa Cathedral", "medium": "Mosaic", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 16, "title": "Christ in Majesty (Book of Kells folio)", "tradition": "Western", "type": "Maiestas", "century": 9, "country": "Ireland", "museum_site": "Trinity College Dublin", "medium": "Manuscript", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 17, "title": "Maiestas Domini (Lindisfarne Gospels)", "tradition": "Western", "type": "Maiestas", "century": 8, "country": "England", "museum_site": "British Library", "medium": "Manuscript", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 18, "title": "Christ in Majesty (Winchester Bible)", "tradition": "Western", "type": "Maiestas", "century": 12, "country": "England", "museum_site": "Winchester Cathedral Library", "medium": "Manuscript", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 19, "title": "Maiestas Domini (Stavelot Bible)", "tradition": "Western", "type": "Maiestas", "century": 11, "country": "Belgium", "museum_site": "Morgan Library", "medium": "Manuscript", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 20, "title": "Christ in Majesty (Reichenau Gospel)", "tradition": "Western", "type": "Maiestas", "century": 11, "country": "Germany", "museum_site": "Bayerische Staatsbibliothek", "medium": "Manuscript", "throne": 1, "mandorla": 1, "book_open": 0, "halo_cross": 1},
    {"id": 21, "title": "Pantokrator (Saint Catherine Sinai)", "tradition": "Eastern", "type": "Pantokrator", "century": 6, "country": "Egypt", "museum_site": "Saint Catherine’s Monastery", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 22, "title": "Pantokrator (Daphni Mosaic)", "tradition": "Eastern", "type": "Pantokrator", "century": 11, "country": "Greece", "museum_site": "Daphni Monastery", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 23, "title": "Pantokrator (Hosios Loukas Dome)", "tradition": "Eastern", "type": "Pantokrator", "century": 11, "country": "Greece", "museum_site": "Hosios Loukas", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 24, "title": "Pantokrator (Nea Moni Chios)", "tradition": "Eastern", "type": "Pantokrator", "century": 11, "country": "Greece", "museum_site": "Nea Moni", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 25, "title": "Pantokrator (Hagia Sophia Deesis Christ)", "tradition": "Eastern", "type": "Pantokrator", "century": 13, "country": "Turkey", "museum_site": "Hagia Sophia", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 26, "title": "Pantokrator (Chora Church)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Turkey", "museum_site": "Kariye Mosque/Museum", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 27, "title": "Pantokrator (Studenica)", "tradition": "Eastern", "type": "Pantokrator", "century": 13, "country": "Serbia", "museum_site": "Studenica Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 28, "title": "Pantokrator (Sopocani)", "tradition": "Eastern", "type": "Pantokrator", "century": 13, "country": "Serbia", "museum_site": "Sopocani Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 29, "title": "Pantokrator (Decani Dome)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Kosovo", "museum_site": "Visoki Decani", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 30, "title": "Pantokrator (Rila Monastery)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "Rila Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 31, "title": "Pantokrator (Boyana Church)", "tradition": "Eastern", "type": "Pantokrator", "century": 13, "country": "Bulgaria", "museum_site": "Boyana Church", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 32, "title": "Pantokrator (Bachkovo Monastery)", "tradition": "Eastern", "type": "Pantokrator", "century": 17, "country": "Bulgaria", "museum_site": "Bachkovo Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 33, "title": "Pantokrator (Nerezi)", "tradition": "Eastern", "type": "Pantokrator", "century": 12, "country": "North Macedonia", "museum_site": "St Panteleimon Nerezi", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 34, "title": "Pantokrator (Gračanica)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Kosovo", "museum_site": "Gracanica Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 35, "title": "Pantokrator (Mistra Peribleptos)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Greece", "museum_site": "Mystras", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 36, "title": "Pantokrator (Mount Athos Vatopedi)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Greece", "museum_site": "Mount Athos Vatopedi", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 37, "title": "Pantokrator (Mount Athos Iviron)", "tradition": "Eastern", "type": "Pantokrator", "century": 15, "country": "Greece", "museum_site": "Mount Athos Iviron", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 38, "title": "Pantokrator (Novgorod Savior)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Russia", "museum_site": "Tretyakov Gallery", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 39, "title": "Pantokrator (Andrei Rublev school)", "tradition": "Eastern", "type": "Pantokrator", "century": 15, "country": "Russia", "museum_site": "Tretyakov Gallery", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 40, "title": "Pantokrator (Yaroslavl)", "tradition": "Eastern", "type": "Pantokrator", "century": 17, "country": "Russia", "museum_site": "Yaroslavl Museum", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 41, "title": "Pantokrator (St Sophia Kyiv)", "tradition": "Eastern", "type": "Pantokrator", "century": 11, "country": "Ukraine", "museum_site": "Saint Sophia Kyiv", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 42, "title": "Pantokrator (Mirozhsky Monastery)", "tradition": "Eastern", "type": "Pantokrator", "century": 12, "country": "Russia", "museum_site": "Mirozhsky Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 43, "title": "Pantokrator (Gelati)", "tradition": "Eastern", "type": "Pantokrator", "century": 12, "country": "Georgia", "museum_site": "Gelati Monastery", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 44, "title": "Pantokrator (Martvili)", "tradition": "Eastern", "type": "Pantokrator", "century": 14, "country": "Georgia", "museum_site": "Martvili Monastery", "medium": "Fresco", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 45, "title": "Pantokrator (Aghtamar)", "tradition": "Eastern", "type": "Pantokrator", "century": 10, "country": "Armenia/Akdamar", "museum_site": "Cathedral of the Holy Cross", "medium": "Relief", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 46, "title": "Pantokrator (Etchmiadzin)", "tradition": "Eastern", "type": "Pantokrator", "century": 17, "country": "Armenia", "museum_site": "Etchmiadzin Cathedral", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 47, "title": "Pantokrator (Coptic Cairo)", "tradition": "Eastern", "type": "Pantokrator", "century": 13, "country": "Egypt", "museum_site": "Coptic Museum", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 48, "title": "Pantokrator (Balamand)", "tradition": "Eastern", "type": "Pantokrator", "century": 18, "country": "Lebanon", "museum_site": "Balamand Monastery", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 49, "title": "Pantokrator (St Mark Belgrade)", "tradition": "Eastern", "type": "Pantokrator", "century": 20, "country": "Serbia", "museum_site": "St Mark Church", "medium": "Mosaic", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1},
    {"id": 50, "title": "Pantokrator (Modern Neo-Byzantine Athens)", "tradition": "Eastern", "type": "Pantokrator", "century": 20, "country": "Greece", "museum_site": "Athens Cathedral", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 0, "halo_cross": 1}
]

# %%
df = pd.DataFrame(artworks_data)

df
# Out:
#     id                                      title tradition         type  \
# 0    1  Christ in Majesty (Sant Climent de Taull)   Western     Maiestas
# 1    2      Maiestas Domini (San Isidoro de Leon)   Western     Maiestas
# 2    3         Christ in Majesty (Urgell frontal)   Western     Maiestas
# 3    4            Christ in Majesty (Vic frontal)   Western     Maiestas
# 4    5           Maiestas Domini (Moissac Portal)   Western     Maiestas
# 5    6         Christ in Majesty (Autun Tympanum)   Western     Maiestas
# 6    7                Christ in Majesty (Conques)   Western     Maiestas
# 7    8    Maiestas Domini (Chartres Royal Portal)   Western     Maiestas
# 8    9                Christ in Majesty (Vezelay)   Western     Maiestas
# 9   10        Christ in Majesty (Torcello Mosaic)   Western     Maiestas
# 10  11          Christ in Majesty (Monreale Apse)   Western     Maiestas
# 11  12            Christ in Majesty (Cefalu Apse)   Western     Maiestas
# ...

# %%
# Ensure correct data types
df[['throne', 'mandorla', 'book_open']] = df[['throne', 'mandorla', 'book_open']].astype(int)

# Quick validation
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           50 non-null     int64
#  1   title        50 non-null     str
#  2   tradition    50 non-null     str
#  3   type         50 non-null     str
#  4   century      50 non-null     int64
#  5   country      50 non-null     str
#  6   museum_site  50 non-null     str
#  7   medium       50 non-null     str
#  8   throne       50 non-null     int64
#  9   mandorla     50 non-null     int64
#  10  book_open    50 non-null     int64
#  11  halo_cross   50 non-null     int64
# dtypes: int64(6), str(6)
# memory usage: 8.6 KB
# None

# %%
# Grouping by Tradition and Calculating Mean Presence (%)
attributes = ['throne', 'mandorla', 'book_open']
analysis = df.groupby('tradition')[attributes].mean() * 100

print("Percentage presence of attributes by tradition:")
print(analysis)
# Out:
# Percentage presence of attributes by tradition:
#            throne  mandorla  book_open
# tradition
# Eastern       0.0       0.0        0.0
# Western     100.0     100.0       30.0

# %% [markdown]
# #### **Analysis of Iconographic Attributes: Examining the frequency of the Throne, Mandorla, and Open Book across both traditions.**

# %%
# Comparison of Attributes: Maiestas (Western) vs Pantokrator (Eastern)
analysis.T.plot(
    kind='bar',
    figsize=(8, 5),
    color= ['#062238', '#C23758'],
    edgecolor='black'
)

plt.title('Comparison of Attributes: Maiestas (Western) vs Pantokrator (Eastern)',  fontsize=11, fontweight='bold')
plt.ylabel('Presence (%)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### **Chronological Distribution (by century): Understanding how artworks are distributed across time.**

# %%
plt.figure(figsize=(9, 6))
sns.histplot(data=df, x='century', hue='tradition', multiple='dodge', bins=range(6, 22),  palette=['#E7063A','#22021C'])
plt.title('Distribution of Works by Century',  fontsize=11, fontweight='bold')
plt.xlabel('Century')
plt.ylabel('Number of Artworks')
plt.xticks(range(6, 21))
plt.show()

# %% [markdown]
# #### **Geographical Distribution: Identifying the most represented countries in the global dataset.**

# %%
plt.figure(figsize=(10, 10))
df['country'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Spectral')
plt.title('Geographical Distribution of Objects')
plt.ylabel('') # Removes unnecessary side label
plt.show()

# %% [markdown]
# ### **Interpretation of Preliminary Findings**
#
# The visualized results from the primary dataset demonstrate a troubling trend: according to the "global digital footprint," the attribute of the "Open Book" within the Pantokrator iconographic type appears to tend toward zero. From an art historical perspective, this quantitative generalization is fundamentally flawed.
#
# This serves as critical evidence of how algorithmic analysis, when stripped of contextual depth, can produce "scientific facts" that distort actual historical development. The statistical dominance of Western specimens (Maiestas Domini) or early Byzantine mosaics in these datasets creates a false illusion of stagnation in the evolution of Orthodox Christological imagery in the Balkans.

# %% [markdown]
# ### **3. The Samokov School: The Corrective of Tradition**

# %% [markdown]
# To correct this digital anachronism, the project integrates data from the Samokov Iconographic School—the most significant artistic center of the Bulgarian National Revival. The Samokov masters were not merely craftsmen; they represented the intellectual elite of the era, spearheading a large-scale iconographic reform.
#
# The introduction of 15 emblematic works by Hristo Dimitrov, Ivan Dospevski, and Nikola Obrazopisov radically transforms the structure of this study. Here, we encounter the phenomenon of a "living tradition":
#
# - **The Word as Center**: A 100% presence of the Open Book, emphasizing the role of Christ as the Logos—a key element in Balkan Orthodoxy.
#
# - **Cultural Synthesis**: The appearance of the globe and scepter in the works of Ivan Dospevski bears witness to a sophisticated dialogue with Western Baroque art, filtered through the Orthodox canon.
#
# - **Hierarchical Complexity**: The "Christ the Great Hierarch" type demonstrates the dogmatic maturity of the school and its ability to visualize complex theological concepts.

# %% [markdown]
# ### **4. Integration and Comparative Analysis**

# %%
samokov_school_data = [
    {"id": 81, "title": "Christ Pantocrator (Tavalichevo)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Petka Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 90, "title": "Christ Pantocrator (Kyustendil)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Dimitar Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 98, "title": "Christ Pantocrator (Lomnica)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. George Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 107, "title": "Christ Pantocrator (Kyustendil - Assumption)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "Assumption Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 122, "title": "Christ Great Hierarch (Dolno Selo)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. George Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 144, "title": "Christ Pantocrator (Kopilovci)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Dimitar Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 155, "title": "Christ Great Hierarch (Kopilovci)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Dimitar Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 165, "title": "Christ Pantocrator (Perivol)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Dimitar Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 177, "title": "Christ Great Hierarch (Perivol)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Dimitar Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 199, "title": "Christ Pantocrator (Konyavo)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "Transfiguration Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 214, "title": "Christ Great Hierarch (Konyavo)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "Transfiguration Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 222, "title": "Christ Pantocrator (Vaksevo)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "Archangel Michael Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 224, "title": "Christ Pantocrator (Treklyano)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "Holy Trinity Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 228, "title": "Christ Pantocrator (Gorni Korten)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Elijah Church", "medium": "Icon", "throne": 0, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"},
    {"id": 235, "title": "Christ Great Hierarch (Gorni Korten)", "tradition": "Eastern", "type": "Pantokrator", "century": 19, "country": "Bulgaria", "museum_site": "St. Elijah Church", "medium": "Icon", "throne": 1, "mandorla": 0, "book_open": 1, "source": "Local Research/Dissertation"}
]

# %%
# Merging the Datasets
full_df = pd.concat([df, pd.DataFrame(samokov_school_data)], ignore_index=True)

full_df
# Out:
#      id                                      title tradition         type  \
# 0     1  Christ in Majesty (Sant Climent de Taull)   Western     Maiestas
# 1     2      Maiestas Domini (San Isidoro de Leon)   Western     Maiestas
# 2     3         Christ in Majesty (Urgell frontal)   Western     Maiestas
# 3     4            Christ in Majesty (Vic frontal)   Western     Maiestas
# 4     5           Maiestas Domini (Moissac Portal)   Western     Maiestas
# ..  ...                                        ...       ...          ...
# 60  214            Christ Great Hierarch (Konyavo)   Eastern  Pantokrator
# 61  222               Christ Pantocrator (Vaksevo)   Eastern  Pantokrator
# 62  224             Christ Pantocrator (Treklyano)   Eastern  Pantokrator
# 63  228          Christ Pantocrator (Gorni Korten)   Eastern  Pantokrator
# 64  235       Christ Great Hierarch (Gorni Korten)   Eastern  Pantokrator
#
#     century   country               museum_site  medium  throne  mandorla  \
# ...

# %% [markdown]
# #### **Figure 1: Comparative Analysis of "Digital Invisibility"**
#
# This visualization directly addresses the problem of incomplete data. It compares the presence of the "Open Book" attribute in the original dataset (which neglects the Balkans) versus the corrected dataset.

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7, 5))

bars = plt.bar(
    ['Initial Dataset', 'With Samokov School'],
    [pre_correction, post_correction],
    # Magenta for initial data, blue for the Samokov School integration
    color = ['#E7063A','#1A5262'],
    edgecolor='black'
)

plt.title('Impact of Regional Data on Iconographic Interpretation', fontsize=12, fontweight='bold')
plt.ylabel('Presence of Open Book (%)')
plt.ylim(0, 100)

# Value labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 2, f'{yval:.1f}%', ha='center')

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()

# SAVE IMAGE FOR README
plt.savefig('comparison_result.jpg', dpi=300)

plt.show()

# %% [markdown]
# ### **Statistical Reversal and Geographical Dominance**
#
# The visual confirmation of this statistical shift is definitive. The initial null value for the Open Book in Eastern Orthodoxy within global databases is a symptom of an information vacuum. The integration of the Samokov School does not merely adjust the figures to nearly a 70% average for the region; it reveals the dogmatic resilience of the Balkan iconographer as a guardian of the Logos.

# %% [markdown]
# #### **Figure 2: Geographical Distribution of the Textual Symbol**
#
# This visualization demonstrates that regarding "The Word" (the Open Book), Bulgaria is not a mere periphery but a primary center in late Orthodoxy.

# %%
# Filtering objects that feature the open book
book_presence = full_df[full_df['book_open'] == 1]

plt.figure(figsize=(7, 4))
sns.countplot(
    data=book_presence, 
    y='country', 
    order=book_presence['country'].value_counts().index, 
    hue='country', 
    palette='flare', 
    legend=False
)

plt.title('Geographical Distribution of Artworks', fontsize=11, fontweight='bold')
plt.xlabel('Number of Registered Works in the Study', fontsize=12)
plt.ylabel('Country/Region', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# The geographical visualization places Bulgaria at the forefront of this study concerning iconographic density and textual symbols. This underscores the role of Samokov as a leading artistic and spiritual center which, under Ottoman rule, managed to develop and preserve a more detailed and symbolically rich iconography than many state and imperial centers of the same period.

# %% [markdown]
# #### **Figure 3: Chronological Intensity of the Samokov School**
#
# This graph illustrates how the Samokov School "bursts" onto the scene in the 19th century, filling the vacuum in iconographic evolution.

# %%
plt.figure(figsize=(7, 5))

# Splitting the data
original_data = full_df[full_df['source'] != 'Local Research/Dissertation']
samokov_data = full_df[full_df['source'] == 'Local Research/Dissertation']

# Using histplot for accurate representation of fixed periods
sns.histplot(original_data['century'], label='Global Dataset (Diverse Periods)', color='#03152A', kde=True, stat="density", alpha=0.3)
sns.histplot(samokov_data['century'], label='Samokov School (Revival Peak)', color='#F6063E', kde=False, stat="density", alpha=0.6, bins=[18.5, 19.5])

plt.title('Chronological Profile: Global Samples vs. Bulgaria\'s National Revival Contribution', fontsize=11, fontweight='bold')
plt.xlabel('Century', fontsize=10)
plt.ylabel('Relative Density', fontsize=10)
plt.xticks(range(6, 21))
plt.legend()
plt.show()

# %% [markdown]
# #### **Conclusion: Rewriting the Digital Narrative**
#
# The comparative analysis between the primary and corrected datasets reveals an unprecedented statistical jump. This proves that the inclusion of regional archives does not merely "complete" the picture—it rewrites it.
#
# Bulgaria is transformed from "statistical noise" into a dominant factor in the understanding of late Orthodox iconography. This result serves as a call for the large-scale digitization of Balkan heritage as the only path toward an objective global history of art.

# %% [markdown]
# ### **5. Future Development: Computer Vision in Service of Art History**

# %% [markdown]
# The next phase of this research is focused on technological ethics and digital preservation. The proposed Computer Vision methods—ranging from deciphering inscriptions through darkened varnish to the digital reconstruction of physically destroyed icons—are not merely technical innovations. They represent the only available tool for "resurrecting" lost knowledge.
#
# Applying contrast enhancement algorithms to archival footage of the Samokov School will enable art historians to perform paleographic analysis of texts within the Gospels that are currently invisible to the naked eye. This transforms computer science into an ally of memory, preventing the final erasure of works that no longer exist in the physical world.

# %% [markdown]
# Proposed Workflow:
#
# - **Denoising & Contrast Enhancement**: Removing digital noise and boosting contrast to facilitate the reading of inscriptions.
#
# - **Edge Detection**: Identifying original contours beneath damaged or overpainted layers.
#
# - **OCR (Optical Character Recognition)**: Attempting automated recognition of Old Church Slavonic text within the open books.

# %% [markdown]
# As part of the project's future trajectory, the application of the CLAHE (Contrast Limited Adaptive Histogram Equalization) algorithm is envisioned as a key tool for digital restoration and iconographic analysis.
#
# Unlike standard Histogram Equalization, which applies a global transformation to the entire image (often leading to overexposure and artificial noise), CLAHE operates on a local level. The image is divided into small contextual regions (tiles), within each of which local contrast is computed.
#
# Key Advantages of CLAHE in the context of the Samokov School:
#
# - **Overcoming Varnish Degradation**: The algorithm successfully extracts details from severely darkened and oxidized areas of the icons, where the human eye perceives only a black background.
#
# - **Contrast Limiting**: By capping contrast amplification, CLAHE prevents the enhancement of micro-cracks (craquelure) and substrate defects that could be mistaken for fragments of inscriptions.
#
# - **Paleographic Legibility**: This method is critical for visualizing micro-texts in the open books held by Christ, allowing for the precise reading of quotes from the Old Church Slavonic canon, even when the painted layer is partially destroyed.
#
# The application of CLAHE transforms the damaged digital archive from a passive repository into an active source of new scientific information.

# %% [markdown]
# #### Visual Example: Detail Recovery via CLAHE
# Due to the natural aging of varnishes and the accumulation of soot, many icons are nearly invisible to standard sensors. Through the CLAHE algorithm, we can extract hidden details.

# %%
from IPython.display import Image, display
display(Image(filename='icon.jpg', width=400))

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Loading the icon
img = cv2.imread('icon.jpg', 0) # Grayscale for clearer contrast analysis

# Applying CLAHE
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)

# Visualizing the comparison
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.subplot(1, 2, 2), plt.imshow(cl1, cmap='gray'), plt.title('After CLAHE Processing')
plt.show()

# %% [markdown]
# Fig. X: Comparison between the original captured image (left) and the image processed via CLAHE (right).

# %% [markdown]
# ### **6. Conclusion**

# %% [markdown]
# This project demonstrates that the interpretation of digital art historical data is deeply influenced by the representativeness of its sources.
#
# By introducing a focused regional corpus from the Samokov Iconographic School, the study illustrates how the inclusion of local material can significantly enrich the broader analytical framework. Rather than altering established knowledge, such integration helps to reveal layers of cultural continuity and theological expression that may remain less visible in large-scale datasets.
#
# The results highlight the importance of approaching digital analysis not only as a technical process, but also as a contextual and interpretative practice—one that benefits from the dialogue between global accessibility and regional specificity.
#
# In this sense, the contribution of Bulgarian iconography, and particularly the Samokov School, offers a meaningful perspective within the wider history of Orthodox art. Its integration into digital research environments supports a more balanced and comprehensive understanding of visual culture.
#
# Ultimately, this project suggests that the future of Digital Art History lies in the careful combination of computational methods with domain expertise, where technology serves not as a replacement for interpretation, but as a tool for its expansion and preservation.

# %% [markdown]
# ### **7. References & Academic Foundation**
#
# This project is a digital extension and visualization of the datasets explored in:
# * **Desislava Strahilova Georgieva**, "THE SAMOKOV PAINTERS IN THE REVIVAL CHURCHES OF THE KYUSTENDIL REGION", PhD Dissertation, National Academy of Arts - Sofia, 2006.
#
# > **Context**: The analysis focuses on the intersection of traditional art history and contemporary Computer Vision methods for the preservation of cultural heritage.
